# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelaMichelleCorreaLopez128/UIII-Act-11-Proyecto-de-simulaci-n-Angela-Correa-0037/blob/main/UIII_Act_11_Proyecto_de_simulaci%C3%B3n_Angela_Correa_0037.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Angela Michelle Correa Lopez NL = 14 Fecha 26/Mayo/2026
# ### Ejercicio 14 Joyero 💍:
# ↪ Atributos: Materiales (oro/plata), técnica de engaste, valor de inventario, certificados de autenticidad, diseño propio y tienda.

# %%
# --- PROGRAMA SIMULADOR DE ASISTENTE DE JOYERÍA (IA INTEGRADA) ---

# El diccionario/lista empieza vacío (se irán agregando las joyas)
joyero = []

# Función para mostrar de forma atractiva las joyas registradas en forma de tabla
def mostrar_joyas():
    if len(joyero) == 0:
        print("\n[Asistente] 📭 El joyero está vacío actualmente.")
        return

    print("\n" + "="*95)
    # Encabezados con formato de columnas alineadas
    print(f"{'Material':<12} | {'Técnica':<15} | {'Valor ($)':<12} | {'Certificado':<13} | {'Diseño Propio':<15} | {'Tienda Venta':<15}")
    print("="*95)

    # Ciclo for para recorrer la lista de diccionarios y mostrar la información bien distribuida
    for joya in joyero:
        print(f"{joya['Material']:<12} | {joya['Técnica']:<15} | {joya['Valor']:<12} | {joya['Certificado']:<13} | {joya['Diseño Propio']:<15} | {joya['Tienda']:<15}")
    print("="*95 + "\n")

# Función que procesa de manera "inteligente" una recomendación basada en el inventario
def asistente_ia():
    if len(joyero) == 0:
        print("\n🤖 [IA]: No tengo datos suficientes en el joyero para darte un reporte.")
        return

    print("\n🤖 [IA Analizando Inventario...]")
    total_joyas = len(joyero)
    oro_count = 0
    valor_total = 0

    for j in joyero:
        # Sumamos el valor del inventario (convertido a entero para operar)
        valor_total += int(j['Valor'])
        # Contamos cuántas joyas son de oro (ignorando mayúsculas/minúsculas)
        if j['Material'].lower() == "oro":
            oro_count += 1

    print(f"-> Actualmente gestionas {total_joyas} pieza(s) en total.")
    print(f"-> El valor acumulado en tu inventario es de: ${valor_total} USD.")

    # Elif e If para simular la toma de decisiones o diagnóstico de la IA
    if oro_count > (total_joyas / 2):
        print("💡 [Sugerencia IA]: Tu catálogo destaca en Alta Joyería (predomina el Oro). ¡Buen margen de ganancia!")
    elif oro_count == 0:
        print("💡 [Sugerencia IA]: Tu colección es puramente de Plata u otros materiales. Ideal para un público juvenil.")
    else:
        print("💡 [Sugerencia IA]: Tienes un inventario equilibrado entre Oro y Plata.")

# --- MENÚ INTERACTIVO PRINCIPAL ---
while True:
    print("✨ --- BIENVENIDO AL ASISTENTE VIRTUAL DE TU JOYERO --- ✨")
    print("1. Agregar una nueva joya")
    print("2. Ver inventario completo (Tabla)")
    print("3. Buscar joya (por Material)")
    print("4. Modificar datos de una joya")
    print("5. Eliminar una joya")
    print("6. Consultar al Asistente IA (Análisis de datos)")
    print("7. Salir del programa")

    opcion = input("Selecciona una opción (1-7): ")

    # ============================================
    # 1. AGREGAR
    # ============================================
    if opcion == "1":
        print("\n--- Registro de Nueva Joya ---")
        material = input("¿Material (Oro / Plata / Otro)?: ")
        tecnica = input("¿Técnica de engaste (Bisel / Pavé / Garras)?: ")
        valor = input("¿Valor de inventario (solo números enteros)?: ")
        certificado = input("¿Tiene certificado de autenticidad? (Sí / No): ")
        diseno = input("¿Es diseño propio? (Sí / No): ")
        tienda = input("¿En qué tienda se ubica asignada?: ")

        # Estructura del diccionario con los atributos solicitados
        nueva_joya = {
            "Material": material,
            "Técnica": tecnica,
            "Valor": valor,
            "Certificado": certificado,
            "Diseño Propio": diseno,
            "Tienda": tienda
        }

        # Agregamos el diccionario a nuestra lista 'joyero'
        joyero.append(nueva_joya)
        print("\n✅ ¡Joya guardada con éxito en el sistema!\n")

    # ============================================
    # 2. MOSTRAR (TABLA)
    # ============================================
    elif opcion == "2":
        mostrar_joyas()

    # ============================================
    # 3. BUSCAR
    # ============================================
    elif opcion == "3":
        if len(joyero) == 0:
            print("\nLa lista está vacía. No hay nada que buscar.")
        else:
            buscar = input("\nEscribe el material de la joya a buscar (ej. Oro / Plata): ")
            encontrado = False

            print("\n" + "="*95)
            print(f"{'Material':<12} | {'Técnica':<15} | {'Valor ($)':<12} | {'Certificado':<13} | {'Diseño Propio':<15} | {'Tienda Venta':<15}")
            print("="*95)

            for joya in joyero:
                # Buscamos ignorando mayúsculas y minúsculas
                if joya["Material"].lower() == buscar.lower():
                    print(f"{joya['Material']:<12} | {joya['Técnica']:<15} | {joya['Valor']:<12} | {joya['Certificado']:<13} | {joya['Diseño Propio']:<15} | {joya['Tienda']:<15}")
                    encontrado = True
            print("="*95)

            if encontrado == False:
                print("❌ No se encontró ninguna joya con ese material.\n")

    # ============================================
    # 4. MODIFICAR
    # ============================================
    elif opcion == "4":
        if len(joyero) == 0:
            print("\nLa lista está vacía. No hay joyas para modificar.")
        else:
            modificar = input("\nEscribe el material de la pieza que deseas modificar: ")
            encontrado = False

            for joya in joyero:
                if joya["Material"].lower() == modificar.lower():
                    print(f"\n--- Pieza encontrada. Introduce los nuevos datos ---")
                    joya["Técnica"] = input("Nueva técnica de engaste: ")
                    joya["Valor"] = input("Nuevo valor de inventario: ")
                    joya["Certificado"] = input("¿Nuevo estado de certificado? (Sí/No): ")
                    joya["Diseño Propio"] = input("¿Es diseño propio actualmente? (Sí/No): ")
                    joya["Tienda"] = input("Nueva tienda asignada: ")

                    print("\n✅ Datos modificados correctamente.\n")
                    encontrado = True
                    break # Detiene la modificación en el primer registro que coincida

            if encontrado == False:
                print("❌ No existe una joya con ese material registrado.\n")

    # ============================================
    # 5. ELIMINAR
    # ============================================
    elif opcion == "5":
        if len(joyero) == 0:
            print("\nLa lista está vacía. No hay nada que eliminar.")
        else:
            eliminar = input("\nEscribe el material de la joya que deseas eliminar de la lista: ")
            encontrado = False

            for joya in joyero:
                if joya["Material"].lower() == eliminar.lower():
                    joyero.remove(joya)
                    print("\n🗑️ Joya eliminada correctamente del sistema.\n")
                    encontrado = True
                    break # Salimos del ciclo para evitar problemas al alterar el tamaño de la lista

            if encontrado == False:
                print("❌ No se encontró ninguna pieza con ese material.\n")

    # ============================================
    # 6. SIMULACIÓN IA
    # ============================================
    elif opcion == "6":
        asistente_ia()

    # ============================================
    # 7. SALIR
    # ============================================
    elif opcion == "7":
        print("\n👋 ¡Gracias por usar el Asistente del Joyero Inteligente! Hasta pronto.")
        break

    else:
        print("\n❌ Opción incorrecta. Por favor, selecciona una opción del 1 al 7.\n")

print("Programa realizado por Angela Michelle Correa Lopez NL = 14")
# Out:
# ✨ --- BIENVENIDO AL ASISTENTE VIRTUAL DE TU JOYERO --- ✨
# 1. Agregar una nueva joya
# 2. Ver inventario completo (Tabla)
# 3. Buscar joya (por Material)
# 4. Modificar datos de una joya
# 5. Eliminar una joya
# 6. Consultar al Asistente IA (Análisis de datos)
# 7. Salir del programa
# Selecciona una opción (1-7): 2
#
# [Asistente] 📭 El joyero está vacío actualmente.
# ✨ --- BIENVENIDO AL ASISTENTE VIRTUAL DE TU JOYERO --- ✨
# 1. Agregar una nueva joya
# 2. Ver inventario completo (Tabla)
# 3. Buscar joya (por Material)
# 4. Modificar datos de una joya
# 5. Eliminar una joya
# 6. Consultar al Asistente IA (Análisis de datos)
# 7. Salir del programa
# Selecciona una opción (1-7): 1
#
# --- Registro de Nueva Joya ---
# ¿Material (Oro / Plata / Otro)?: Oro
# ¿Técnica de engaste (Bisel / Pavé / Garras)?: Bisel
# ¿Valor de inventario (solo números enteros)?: 1900
# ¿Tiene certificado de autenticidad? (Sí / No): Si
# ¿Es diseño propio? (Sí / No): No
# ...

# %% [markdown]
# ![texto vínculo](https://raw.githubusercontent.com/AngelaMichelleCorreaLopez128/UIII-Act-11-Proyecto-de-simulaci-n-Angela-Correa-0037/refs/heads/main/Act%2011%20infografiajoyero.png)
